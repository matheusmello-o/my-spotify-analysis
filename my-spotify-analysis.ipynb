# %%
import pandas as pd

df = pd.read_csv('files/my_data.csv')
df.head()
# Out:
#                      ts                 platform  ms_played  \
# 0  2017-09-27T02:12:44Z     iOS 11.0 (iPhone8,4)     251000
# 1  2022-03-16T01:05:55Z  iOS 15.3.1 (iPhone12,8)     304840
# 2  2019-11-26T18:29:19Z   iOS 13.1.3 (iPhone9,3)       7786
# 3  2017-09-27T15:59:34Z     iOS 11.0 (iPhone8,4)      98221
# 4  2017-12-18T20:14:11Z   iOS 11.1.2 (iPhone8,4)       5642
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                  Crave You                   Daniela Andrade
# 1                   Uprising                              Muse
# 2     Regret - 2015 Remaster                         New Order
# 3                    Part II                          Paramore
# 4      ...Baby One More Time                    Britney Spears
#
#                  master_metadata_album_album_name reason_start reason_end  \
# 0                                       Crave You    trackdone  trackdone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215138 entries, 0 to 215137
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 215138 non-null  object
#  1   platform                           215138 non-null  object
#  2   ms_played                          215138 non-null  int64
#  3   master_metadata_track_name         214038 non-null  object
#  4   master_metadata_album_artist_name  214038 non-null  object
#  5   master_metadata_album_album_name   214038 non-null  object
#  6   reason_start                       212067 non-null  object
#  7   reason_end                         212185 non-null  object
#  8   shuffle                            215138 non-null  bool
#  9   skipped                            35930 non-null   float64
#  10  offline                            215138 non-null  bool
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                           ts                 platform  ms_played  \
# 0       2017-09-27T02:12:44Z     iOS 11.0 (iPhone8,4)     251000
# 1       2022-03-16T01:05:55Z  iOS 15.3.1 (iPhone12,8)     304840
# 2       2019-11-26T18:29:19Z   iOS 13.1.3 (iPhone9,3)       7786
# 3       2017-09-27T15:59:34Z     iOS 11.0 (iPhone8,4)      98221
# 4       2017-12-18T20:14:11Z   iOS 11.1.2 (iPhone8,4)       5642
# ...                      ...                      ...        ...
# 215133  2017-10-01T17:27:37Z   iOS 11.0.1 (iPhone8,4)       4551
# 215134  2022-01-31T20:08:27Z      OS X 12.2.0 [x86 8]     222880
# 215135  2015-10-08T21:10:34Z    iOS 9.0.2 (iPhone7,2)       1811
# 215136  2016-06-02T17:17:31Z    iOS 9.3.2 (iPhone8,1)          0
# 215137  2016-01-02T15:30:26Z      iOS 9.2 (iPhone7,2)     216967
#
#                           master_metadata_track_name  \
# 0                                          Crave You
# ...
