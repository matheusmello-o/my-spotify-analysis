# %%
import pandas as pd
from glob import glob

files = glob('files/*.json')
df = pd.concat(pd.read_json(f) for f in files)
df.head()
# Out:
#                      ts           username                 platform  \
# 0  2017-09-27T02:12:44Z  matheusmellocunha     iOS 11.0 (iPhone8,4)
# 1  2022-03-16T01:05:55Z  matheusmellocunha  iOS 15.3.1 (iPhone12,8)
# 2  2019-11-26T18:29:19Z  matheusmellocunha   iOS 13.1.3 (iPhone9,3)
# 3  2017-09-27T15:59:34Z  matheusmellocunha     iOS 11.0 (iPhone8,4)
# 4  2017-12-18T20:14:11Z  matheusmellocunha   iOS 11.1.2 (iPhone8,4)
#
#    ms_played conn_country ip_addr_decrypted user_agent_decrypted  \
# 0     251000           BR     177.178.71.71              unknown
# 1     304840           BR      201.17.96.65              unknown
# 2       7786           BR     189.92.198.47              unknown
# 3      98221           BR    186.243.146.27              unknown
# 4       5642           BR    189.104.225.92              unknown
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                  Crave You                   Daniela Andrade
# ...
